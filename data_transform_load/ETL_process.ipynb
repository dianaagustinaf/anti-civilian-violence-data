# %% [markdown]
# ## Dependancies

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
from datetime import datetime

# %% [markdown]
# ## Import Clean Datasets

# %%
civilian_df = pd.read_csv("../Project-3/civilians_Jun10.csv", index_col=False, encoding='ISO-8859-1')

# %% [markdown]
# ## Data Exploration

# %%
civilian_df.head()
# Out:
#    ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY       EVENT_DATE  YEAR  TIME_PRECISION  \
# 0    0          XKX1                 1  05-January-2018  2018               1
# 1    0          XKX8                 8  16-January-2018  2018               1
# 2    0         XKX16                16    03-March-2018  2018               1
# 3    0         XKX17                17    05-March-2018  2018               1
# 4    0         XKX23                23    20-March-2018  2018               1
#
#                    EVENT_TYPE                      SUB_EVENT_TYPE  \
# 0                       Riots               Violent demonstration
# 1  Violence against civilians                              Attack
# 2                    Protests  Excessive force against protesters
# 3  Violence against civilians                              Attack
# 4  Violence against civilians                              Attack
#
#                                 ACTOR1                   ASSOC_ACTOR_1  ...  \
# 0                     Rioters (Kosovo)                             NaN  ...
# 1    Unidentified Armed Group (Kosovo)                             NaN  ...
# 2  Police Forces of Kosovo (2017-2020)                             NaN  ...
# 3    Unidentified Armed Group (Kosovo)   Serbian Ethnic Group (Kosovo)  ...
# 4    Unidentified Armed Group (Kosovo)  Albanian Ethnic Group (Kosovo)  ...
#
#    ADMIN3           LOCATION LATITUDE  LONGITUDE  GEO_PRECISION  \
# 0     NaN            Gjakova   42.380     20.431              1
# 1     NaN    North Mitrovica   42.895     20.865              1
# 2     NaN          Mitrovica   42.887     20.867              1
# 3     NaN    North Mitrovica   42.895     20.865              1
# 4     NaN  Donji Dragoljevac   42.761     20.490              1
#
#                            SOURCE          SOURCE_SCALE  \
# 0  Local Source; Vecernje Novosti  Subnational-Regional
# 1                     Intellinews         International
# 2                           UNMIK              National
# 3                           UNMIK              National
# 4                          KoSSev              National
#
#                                                NOTES FATALITIES   TIMESTAMP
# 0  On 5 January 2018, a group of Kosovo Albanians...          0  1649355992
# 1  On the morning of January 16, prominent Kosova...          1  1553853272
# 2  On 3 March 2018, 2018 in Mitrovica, police use...          0  1652375201
# 3  On 5 March 2018, 2018 in North Mitrovica, Koso...          0  1652375201
# 4  On 20 March 2018, 2018 in Dragoljevac, Kosovo,...          0  1652375201
#
# [5 rows x 29 columns]

# %%
civilian_df.dtypes
# Out:
# ISO                   int64
# EVENT_ID_CNTY        object
# EVENT_ID_NO_CNTY      int64
# EVENT_DATE           object
# YEAR                  int64
# TIME_PRECISION        int64
# EVENT_TYPE           object
# SUB_EVENT_TYPE       object
# ACTOR1               object
# ASSOC_ACTOR_1        object
# INTER1                int64
# ACTOR2               object
# ASSOC_ACTOR_2        object
# INTER2                int64
# INTERACTION           int64
# REGION               object
# COUNTRY              object
# ADMIN1               object
# ADMIN2               object
# ADMIN3               object
# LOCATION             object
# LATITUDE            float64
# LONGITUDE           float64
# GEO_PRECISION         int64
# SOURCE               object
# SOURCE_SCALE         object
# NOTES                object
# FATALITIES            int64
# TIMESTAMP             int64
# dtype: object

# %% [markdown]
# ## Data Cleansing

# %%
civilian_df.set_index('ISO', inplace=True)

# %%
civilian_df.head()
# Out:
#     EVENT_ID_CNTY  EVENT_ID_NO_CNTY       EVENT_DATE  YEAR  TIME_PRECISION  \
# ISO
# 0            XKX1                 1  05-January-2018  2018               1
# 0            XKX8                 8  16-January-2018  2018               1
# 0           XKX16                16    03-March-2018  2018               1
# 0           XKX17                17    05-March-2018  2018               1
# 0           XKX23                23    20-March-2018  2018               1
#
#                      EVENT_TYPE                      SUB_EVENT_TYPE  \
# ISO
# 0                         Riots               Violent demonstration
# 0    Violence against civilians                              Attack
# 0                      Protests  Excessive force against protesters
# 0    Violence against civilians                              Attack
# 0    Violence against civilians                              Attack
#
#                                   ACTOR1                   ASSOC_ACTOR_1  \
# ISO
# 0                       Rioters (Kosovo)                             NaN
# 0      Unidentified Armed Group (Kosovo)                             NaN
# 0    Police Forces of Kosovo (2017-2020)                             NaN
# 0      Unidentified Armed Group (Kosovo)   Serbian Ethnic Group (Kosovo)
# 0      Unidentified Armed Group (Kosovo)  Albanian Ethnic Group (Kosovo)
#
#      INTER1  ... ADMIN3           LOCATION  LATITUDE  LONGITUDE GEO_PRECISION  \
# ISO          ...
# 0         5  ...    NaN            Gjakova    42.380     20.431             1
# 0         3  ...    NaN    North Mitrovica    42.895     20.865             1
# 0         1  ...    NaN          Mitrovica    42.887     20.867             1
# 0         3  ...    NaN    North Mitrovica    42.895     20.865             1
# 0         3  ...    NaN  Donji Dragoljevac    42.761     20.490             1
#
#                              SOURCE          SOURCE_SCALE  \
# ISO
# 0    Local Source; Vecernje Novosti  Subnational-Regional
# 0                       Intellinews         International
# 0                             UNMIK              National
# 0                             UNMIK              National
# 0                            KoSSev              National
#
#                                                  NOTES FATALITIES   TIMESTAMP
# ISO
# 0    On 5 January 2018, a group of Kosovo Albanians...          0  1649355992
# 0    On the morning of January 16, prominent Kosova...          1  1553853272
# 0    On 3 March 2018, 2018 in Mitrovica, police use...          0  1652375201
# 0    On 5 March 2018, 2018 in North Mitrovica, Koso...          0  1652375201
# 0    On 20 March 2018, 2018 in Dragoljevac, Kosovo,...          0  1652375201
#
# [5 rows x 28 columns]

# %%
civilian_df.drop(['EVENT_ID_CNTY', 'EVENT_ID_NO_CNTY', 
                  'TIME_PRECISION', 'ASSOC_ACTOR_1', 
                  'INTER1', 'ACTOR2', 'ASSOC_ACTOR_2', 
                  'INTER2', 'INTERACTION', 'ADMIN1', 
                  'ADMIN2', 'ADMIN3'], axis=1, inplace=True)

# %%
civilian_df.head()
# Out:
#           EVENT_DATE  YEAR                  EVENT_TYPE  \
# ISO
# 0    05-January-2018  2018                       Riots
# 0    16-January-2018  2018  Violence against civilians
# 0      03-March-2018  2018                    Protests
# 0      05-March-2018  2018  Violence against civilians
# 0      20-March-2018  2018  Violence against civilians
#
#                          SUB_EVENT_TYPE                               ACTOR1  \
# ISO
# 0                 Violent demonstration                     Rioters (Kosovo)
# 0                                Attack    Unidentified Armed Group (Kosovo)
# 0    Excessive force against protesters  Police Forces of Kosovo (2017-2020)
# 0                                Attack    Unidentified Armed Group (Kosovo)
# 0                                Attack    Unidentified Armed Group (Kosovo)
#
#      REGION COUNTRY           LOCATION  LATITUDE  LONGITUDE  GEO_PRECISION  \
# ISO
# 0    Europe  Kosovo            Gjakova    42.380     20.431              1
# 0    Europe  Kosovo    North Mitrovica    42.895     20.865              1
# 0    Europe  Kosovo          Mitrovica    42.887     20.867              1
# 0    Europe  Kosovo    North Mitrovica    42.895     20.865              1
# 0    Europe  Kosovo  Donji Dragoljevac    42.761     20.490              1
#
#                              SOURCE          SOURCE_SCALE  \
# ISO
# 0    Local Source; Vecernje Novosti  Subnational-Regional
# 0                       Intellinews         International
# 0                             UNMIK              National
# 0                             UNMIK              National
# 0                            KoSSev              National
#
#                                                  NOTES  FATALITIES   TIMESTAMP
# ISO
# 0    On 5 January 2018, a group of Kosovo Albanians...           0  1649355992
# 0    On the morning of January 16, prominent Kosova...           1  1553853272
# 0    On 3 March 2018, 2018 in Mitrovica, police use...           0  1652375201
# 0    On 5 March 2018, 2018 in North Mitrovica, Koso...           0  1652375201
# 0    On 20 March 2018, 2018 in Dragoljevac, Kosovo,...           0  1652375201

# %%
civilian_df['EVENT_DATE'] = pd.to_datetime(civilian_df['EVENT_DATE'], infer_datetime_format=True)

# %%
civilian_df.dtypes
# Out:
# EVENT_DATE        datetime64[ns]
# YEAR                       int64
# EVENT_TYPE                object
# SUB_EVENT_TYPE            object
# ACTOR1                    object
# REGION                    object
# COUNTRY                   object
# LOCATION                  object
# LATITUDE                 float64
# LONGITUDE                float64
# GEO_PRECISION              int64
# SOURCE                    object
# SOURCE_SCALE              object
# NOTES                     object
# FATALITIES                 int64
# TIMESTAMP                  int64
# dtype: object

# %%
civilian_df = pd.DataFrame(civilian_df)
new_df = civilian_df.loc[civilian_df["YEAR"] > 2017]

# %%
new_df.head()
# Out:
#     EVENT_DATE  YEAR                  EVENT_TYPE  \
# ISO
# 0   2018-01-05  2018                       Riots
# 0   2018-01-16  2018  Violence against civilians
# 0   2018-03-03  2018                    Protests
# 0   2018-03-05  2018  Violence against civilians
# 0   2018-03-20  2018  Violence against civilians
#
#                          SUB_EVENT_TYPE                               ACTOR1  \
# ISO
# 0                 Violent demonstration                     Rioters (Kosovo)
# 0                                Attack    Unidentified Armed Group (Kosovo)
# 0    Excessive force against protesters  Police Forces of Kosovo (2017-2020)
# 0                                Attack    Unidentified Armed Group (Kosovo)
# 0                                Attack    Unidentified Armed Group (Kosovo)
#
#      REGION COUNTRY           LOCATION  LATITUDE  LONGITUDE  GEO_PRECISION  \
# ISO
# 0    Europe  Kosovo            Gjakova    42.380     20.431              1
# 0    Europe  Kosovo    North Mitrovica    42.895     20.865              1
# 0    Europe  Kosovo          Mitrovica    42.887     20.867              1
# 0    Europe  Kosovo    North Mitrovica    42.895     20.865              1
# 0    Europe  Kosovo  Donji Dragoljevac    42.761     20.490              1
#
#                              SOURCE          SOURCE_SCALE  \
# ISO
# 0    Local Source; Vecernje Novosti  Subnational-Regional
# 0                       Intellinews         International
# 0                             UNMIK              National
# 0                             UNMIK              National
# 0                            KoSSev              National
#
#                                                  NOTES  FATALITIES   TIMESTAMP
# ISO
# 0    On 5 January 2018, a group of Kosovo Albanians...           0  1649355992
# 0    On the morning of January 16, prominent Kosova...           1  1553853272
# 0    On 3 March 2018, 2018 in Mitrovica, police use...           0  1652375201
# 0    On 5 March 2018, 2018 in North Mitrovica, Koso...           0  1652375201
# 0    On 20 March 2018, 2018 in Dragoljevac, Kosovo,...           0  1652375201

# %%
clean_df = new_df.query("EVENT_TYPE == 'Violence against civilians'")

# %%
clean_df.head()
# Out:
#     EVENT_DATE  YEAR                  EVENT_TYPE SUB_EVENT_TYPE  \
# ISO
# 0   2018-01-16  2018  Violence against civilians         Attack
# 0   2018-03-05  2018  Violence against civilians         Attack
# 0   2018-03-20  2018  Violence against civilians         Attack
# 0   2018-03-21  2018  Violence against civilians         Attack
# 0   2018-03-26  2018  Violence against civilians         Attack
#
#                                   ACTOR1  REGION COUNTRY           LOCATION  \
# ISO
# 0      Unidentified Armed Group (Kosovo)  Europe  Kosovo    North Mitrovica
# 0      Unidentified Armed Group (Kosovo)  Europe  Kosovo    North Mitrovica
# 0      Unidentified Armed Group (Kosovo)  Europe  Kosovo  Donji Dragoljevac
# 0                 LV: Self-Determination  Europe  Kosovo           Pristina
# 0    Police Forces of Kosovo (2017-2020)  Europe  Kosovo    North Mitrovica
#
#      LATITUDE  LONGITUDE  GEO_PRECISION                           SOURCE  \
# ISO
# 0      42.895     20.865              1                      Intellinews
# 0      42.895     20.865              1                            UNMIK
# 0      42.761     20.490              1                           KoSSev
# 0      42.667     21.172              1                              AFP
# 0      42.895     20.865              1  RTK; AP; Politika; Local Source
#
#              SOURCE_SCALE                                              NOTES  \
# ISO
# 0           International  On the morning of January 16, prominent Kosova...
# 0                National  On 5 March 2018, 2018 in North Mitrovica, Koso...
# 0                National  On 20 March 2018, 2018 in Dragoljevac, Kosovo,...
# 0           International  On 21 March 2018, 2018 in Pristina, Kosovo, te...
# 0    Subnational-National  On 26 March 2018, Kosovo police arrested the D...
#
#      FATALITIES   TIMESTAMP
# ISO
# 0             1  1553853272
# 0             0  1652375201
# 0             0  1652375201
# 0             0  1652375201
# 0             0  1649355992

# %%
clean_df = clean_df.rename({"ISO": "iso", "EVENT_DATE": "event_date", 
                                    "YEAR": "year", "EVENT_TYPE": "event_type", 
                                    "SUB_EVENT_TYPE": "sub_event_type", "ACTOR1": "actor1", 
                                    "REGION": "region", "COUNTRY": "country", 
                                    "LOCATION": "location", "LATITUDE": "latitude", 
                                    "LONGITUDE": "longitude", "GEO_PRECISION": "geo_precision", 
                                    "SOURCE": "source", "SOURCE_SCALE": "source_scale", 
                                    "NOTES": "notes", "FATALITIES": "fatalities", 
                                    "TIMESTAMP": "timestamp"}, axis=1)

# %%
clean_df.head()
# Out:
#     event_date  year                  event_type sub_event_type  \
# ISO
# 0   2018-01-16  2018  Violence against civilians         Attack
# 0   2018-03-05  2018  Violence against civilians         Attack
# 0   2018-03-20  2018  Violence against civilians         Attack
# 0   2018-03-21  2018  Violence against civilians         Attack
# 0   2018-03-26  2018  Violence against civilians         Attack
#
#                                   actor1  region country           location  \
# ISO
# 0      Unidentified Armed Group (Kosovo)  Europe  Kosovo    North Mitrovica
# 0      Unidentified Armed Group (Kosovo)  Europe  Kosovo    North Mitrovica
# 0      Unidentified Armed Group (Kosovo)  Europe  Kosovo  Donji Dragoljevac
# 0                 LV: Self-Determination  Europe  Kosovo           Pristina
# 0    Police Forces of Kosovo (2017-2020)  Europe  Kosovo    North Mitrovica
#
#      latitude  longitude  geo_precision                           source  \
# ISO
# 0      42.895     20.865              1                      Intellinews
# 0      42.895     20.865              1                            UNMIK
# 0      42.761     20.490              1                           KoSSev
# 0      42.667     21.172              1                              AFP
# 0      42.895     20.865              1  RTK; AP; Politika; Local Source
#
#              source_scale                                              notes  \
# ISO
# 0           International  On the morning of January 16, prominent Kosova...
# 0                National  On 5 March 2018, 2018 in North Mitrovica, Koso...
# 0                National  On 20 March 2018, 2018 in Dragoljevac, Kosovo,...
# 0           International  On 21 March 2018, 2018 in Pristina, Kosovo, te...
# 0    Subnational-National  On 26 March 2018, Kosovo police arrested the D...
#
#      fatalities   timestamp
# ISO
# 0             1  1553853272
# 0             0  1652375201
# 0             0  1652375201
# 0             0  1652375201
# 0             0  1649355992

# %%
clean_df.to_csv('anti_violence_data.csv', index=False)

# %% [markdown]
# ## Create Database Connection

# %%
from config import password

# %%
connection_string = (f'postgres:{password}@localhost:5432/anti_violence_db')
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# /Users/missshola/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.
# ['anti_violence_data']

# %% [markdown]
# ## Load DataFrames into database

# %%
clean_df.to_sql(name='vac_data', con=engine, if_exists='append', index=True)
